# %%
#factorize x^8-1
p=x^8-1
p.factor()
# Out:
# (x^4 + 1)*(x^2 + 1)*(x + 1)*(x - 1)

# %%
factor((2*x^2)/(x^3+1)+3*x/(x^2-1))
# Out:
# (5*x^2 - 5*x + 3)*x/((x^2 - x + 1)*(x + 1)*(x - 1))

# %%
p = sin(x)^2+cos(x)^2
p.trig_simplify()
# Out:
# 1

# %%
f = exp(x)+log(x)
f.subs(x=1)
# Out:
# e

# %%
eq = x^2-4*x+3 == 0
solve(eq,x)
# Out:
# [x == 3, x == 1]

# %%
find_root(x-cos(x),-1,1)
# Out:
# 0.7390851332151607

# %%
find_root(x^5-3*x^3-1, -2,2)
# Out:
# 1.7823087800458832

# %%
var("y")
syst = [4*x+3*y==10, 3*x-y==1]
solve(syst,x,y)
# Out:
# [[x == 1, y == 2]]

# %%
g=exp(x)-sin(x)
diff(g,x)
integrate(g,x)
# Out:
# cos(x) + e^x

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
limit((cos(x)+1)/(x-pi),x=pi)
# Out:
# 0

# %%
f(x)=sin(x)
plot(sin(x), 0, 2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sin(x),-100,100)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=1/x
plot(1/x,-1,1,ymax=10,ymin=-10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=1/x
plot(1/x,-1,1,ymax=10,ymin=-10, detect_poles = True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x)=1/x
plot(1/x,-1,1,ymax=10,ymin=-10, detect_poles = False)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x)=1/x
plot(1/(x-1),0,2,ymax=10,ymin=-10, detect_poles = False)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#13
#x = t-x^2
#y = t-t^3 # t in [-2,2]
var('t')
parametric_plot((2-t^2,t-t^3),(t,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#13
#x = t-x^2
#y = t-t^3 # t in [-2,2]
var('t')
parametric_plot((2-t^2,t-t^3),(t,-2,2), ymax=2, ymin=-2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,pi),ymax=2,ymin=-2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
implicit_plot(x^2-2*x*y-y^2==1,(x,-5,5),(y,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(x^2+y^2,(x,-2,2),(y,-2,2))
# Out:
# Graphics3d Object
