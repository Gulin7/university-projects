# %%
1+1
# Out:
# 2

# %%
var('t')
diff(sin(t),t)
# Out:
# cos(t)

# %%
var('t')
diff(sin(t),t,4)
# Out:
# sin(t)

# %%
var('t')
diff(cos(t),t,4)
# Out:
# cos(t)

# %%
t=var('t')
x=function('x')(t)
eq=(diff(x,t,2))+x == 0
desolve(eq,x)
# Out:
# _K2*cos(t) + _K1*sin(t)

# %%
t=var('t')
x=function('x')(t)
eq=4*(diff(x,t,2))+8*(diff(x,t,1)) +5*x == 0
desolve(eq,x)
# Out:
# (_K2*cos(1/2*t) + _K1*sin(1/2*t))*e^(-t)

# %%
t=var('t')
x=function('x')(t)
eq=(diff(x,t,2))-3*(diff(x,t,1)) +2*x == 0
desolve(eq,x)
# Out:
# _K1*e^(2*t) + _K2*e^t

# %%
t=var('t')
x=function('x')(t)
eq=diff(x,t) == -t*x
desolve(eq,x)
# Out:
# _C*e^(-1/2*t^2)

# %%
t=var('t')
x=function('x')(t)
eq6=diff(x,t,2)+x == 0
desolve(eq6,x,ics=[pi/2,1,-2])
# Out:
# 2*cos(t) + sin(t)

# %%
sol6 = desolve(eq6,x,ics=[pi/2,1,-2])
plot(sol6,t,-10,10)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x=function('x')(t)
eq7=4*diff(x,t,2)+8*diff(x,t)+5*x == 0
desolve(eq7,x,ics=[0,0,0.5])
# Out:
# e^(-t)*sin(1/2*t)

# %%
sol7 = desolve(eq7,x,ics=[0,0,0.5])
plot(sol7,-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x=function('x')(t)
eq8=diff(x,t,2)-3*diff(x,t)+2*x == 0
desolve(eq8,x,ics=[0,2,3])
# Out:
# e^(2*t) + e^t

# %%
sol8 = desolve(eq8,x,ics=[0,2,3])
plot(sol8, -10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x=function('x')(t)
eq9=diff(x,t,2)+5*x == 0
desolve(eq9,x,contrib_ode=true)
# Out:
# _K2*cos(sqrt(5)*t) + _K1*sin(sqrt(5)*t)

# %%
t=var('t')
x=function('x')(t)
eq10=diff(x,t,2)+x == 0
desolve(eq10,x,ics=[0,0,pi,0])
# Out:
# r2*sin(t)

# %%
t=var('t')
x=function('x')(t)
eq13=diff(x,t)+x == 15
desolve(eq13,x)
# Out:
# (_C + 15*e^t)*e^(-t)

# %%
t=var('t')
x=function('x')(t)
eq14=diff(x,t)+x == 2*e^t-7*e^(-3*t)
desolve(eq14,x)
# Out:
# 1/2*(2*_C + 2*e^(2*t) + 7*e^(-2*t))*e^(-t)

# %%
t=var('t')
x=function('x')(t)
eq15=diff(x,t)+x == -t^2+3*t-7
desolve(eq15,x)
# Out:
# -((t^2 - 2*t + 2)*e^t - 3*(t - 1)*e^t - _C + 7*e^t)*e^(-t)

# %%
sol15 = desolve(eq15,x)
sol15.factor()
# Out:
# -(t^2*e^t - 5*t*e^t - _C + 12*e^t)*e^(-t)

# %%
t=var('t')
x=function('x')(t)
eq16=diff(x,t)+x == sin(t)+3*cos(t)
desolve(eq16,x)
# Out:
# 1/2*(3*(cos(t) + sin(t))*e^t - (cos(t) - sin(t))*e^t + 2*_C)*e^(-t)

# %%
t=var('t')
x=function('x')(t)
eq17=diff(x,t)+x == sin(t)
desolve(eq17,x)
# Out:
# -1/2*((cos(t) - sin(t))*e^t - 2*_C)*e^(-t)

# %%
t=var('t')
x=function('x')(t)
eq19=diff(x,t,2)+x == sin(t)
desolve(eq19,x)
# Out:
# _K2*cos(t) - 1/2*t*cos(t) + _K1*sin(t)

# %%
t=var('t')
x=function('x')(t)
eq18=diff(x,t)+x == 3*cos(t)
desolve(eq18,x)
# Out:
# 1/2*(3*(cos(t) + sin(t))*e^t + 2*_C)*e^(-t)

# %%
p = (sqrt(5)*cos(t-arctan(1/2)))
p.trig_simplify()
# Out:
# 2*cos(t) + sin(t)
