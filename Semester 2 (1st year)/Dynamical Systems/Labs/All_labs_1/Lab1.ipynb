# %%
1+1
# Out:
# 2

# %%
sqrt(2.)
# Out:
# 1.41421356237310

# %%
exp(1.)
# Out:
# 2.71828182845905

# %%
numerical_approx(pi,digits=5)
# Out:
# 3.1416

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
p=exp(x)+log(x)
p.subs(x=1)
# Out:
# e

# %%
var('x')
solve(x^2-4*x+3==0,x)
# Out:
# [x == 3, x == 1]

# %%
var('y')
solve(x^2*y+2*y-x==0,x)
# Out:
# [x == -1/2*(sqrt(-8*y^2 + 1) - 1)/y, x == 1/2*(sqrt(-8*y^2 + 1) + 1)/y]

# %%
find_root(x-cos(x),-1,1)
# Out:
# 0.7390851332151607

# %%
find_root(x^5-3*x^3-1,-1,0)
# Out:
# -0.7418139304867688

# %%
syst=[4*x+3*y==10,
     3*x-y==1]
solve(syst,x,y)
# Out:
# [[x == 1, y == 2]]

# %%
var('x')
g=exp(x)-sin(x)
g.subs(x=0)
diff(g,x)
# Out:
# -cos(x) + e^x

# %%
var('x')
g=exp(x)-sin(x)
g.subs(x=0)
# Out:
# 1

# %%
var('x')
g=exp(x)-sin(x)
integrate(g,x).subs(x=1)
# Out:
# cos(1) + e

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
plot(sin(x),0,2*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('t')
parametric_plot((2-t^2,t-t^3),(t,-2,2),ymax=2,ymin=-2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
parametric_plot((cos(t),sin(t)),(t,0,2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,y)=x^2-2*x*y-y^2-1
implicit_plot(f(x,y)==0,(x,-5,5),(y,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
H(x,y)=x^2+y^2
plot3d(x^2+y^2,(x,-2,2),(y,-2,2))
g=implicit_plot(x^2+y^2==0,(x,-5,5),(y,-5,5))
for k in range(1,20,3):
    g=g+implicit_plot(x^2+y^2==k,(x,-5,5),(y,-5,5))
show(g)
# Out:
# Graphics object consisting of 8 graphics primitives
