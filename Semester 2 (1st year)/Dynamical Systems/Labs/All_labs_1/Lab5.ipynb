# %%
# a
x,y=var('x y')
solve([2*x-x^2-x*y==0, -y+x*y==0],x,y)
# Out:
# [[x == 0, y == 0], [x == 2, y == 0], [x == 1, y == 1]]

# %%
# b
x,y=var('x y')
f = (2*x-x^2-x*y, -y+x*y)
jac = jacobian(f,(x,y))
jac
# Out:
# [-2*x - y + 2           -x]
# [           y        x - 1]

# %%
A1=jac.subs(x=0,y=0)
A1
# Out:
# [ 2  0]
# [ 0 -1]

# %%
A1.eigenvalues()
# Out:
# [-1, 2]

# %%
A2=jac.subs(x=2, y=0)
A2
# Out:
# [-2 -2]
# [ 0  1]

# %%
A2.eigenvalues()
# Out:
# [-2, 1]

# %%
A3=jac.subs(x=1, y=1)
A3
# Out:
# [-1 -1]
# [ 1  0]

# %%
A3.eigenvalues()
# Out:
# [-1/2*I*sqrt(3) - 1/2, 1/2*I*sqrt(3) - 1/2]

# %%
#c 
x,y=var('x y')
f = (2*x-x^2-x*y, -y+x*y)
plot_vector_field((f[0],f[1]),(x,-0.2,0.2),(y,-1,1.2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x y')
f = (2*x-x^2-x*y, -y+x*y)
plot_vector_field((f[0],f[1]),(x,0.9,1.1),(y,-1,1.2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x y')
f = (2*x-x^2-x*y, -y+x*y)
plot_vector_field((f[0],f[1]),(x,-1,2.2),(y,-1,1.2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#d
time=srange(0,10,0.1)
ics=(-1.5,3)
sol=desolve_odeint(f,ics,time,[x,y])
p_vectorfield = plot_vector_field((f[0],f[1]),(x,-3,3),(y,-3,3))
for ics in [(0.1,0.2),(0.9,1.1),(1.9,0.1)]:
    sol = desolve_odeint(f,ics,time,[x,y])
    p_vectorfield+=line(zip(sol[:,0], sol[:,1]))
show(p_vectorfield)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#2
x,y=var('x y')
solve([x-2*x*y==0, x^2/2-y==0],x,y)
# Out:
# [[x == 0, y == 0], [x == -1, y == (1/2)], [x == 1, y == (1/2)]]

# %%
f = (x-2*x*y, x^2/2-y)
jac = jacobian(f,(x,y))
jac
# Out:
# [-2*y + 1     -2*x]
# [       x       -1]

# %%
A1=jac.subs(x==0,y==0)
A1
# Out:
# [ 1  0]
# [ 0 -1]

# %%
#3
x,y=var('x y')
f = (y, -4*sin(x))
jac = jacobian(f,(x,y))
jac
# Out:
# [        0         1]
# [-4*cos(x)         0]

# %%
B1=jac.subs(x=0,y=0)
B1
# Out:
# [ 0  1]
# [-4  0]

# %%
B1.eigenvalues()
# Out:
# [-2*I, 2*I]

# %%
#b
x=var('x')
y=function('y')(x)
sol=desolve(diff(y,x)==-4*sin(x)/y,y)
sol*=8
sol
# Out:
# -y(x)^2 == 8*_C - 8*cos(x)

# %%
#c
x,y=var('x y')
H=function('H')(x,y)
H=y^2-8*cos(x)
diff(H,x)*y -4*sin(x)*diff(H,y)
# Out:
# 0 == 0

# %%
import matplotlib.cm
contour_plot(H,(-5,5),(-5,5),fill=true,contours=50,cmap='magma')
# Out:
# Graphics object consisting of 1 graphics primitive
